# %% [markdown]
# ### __Survey__

# %%
import pandas as pd
import os
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt

# %%
# Data of all states
folder_path = "./store-meta"

# List to hold all the state dfs
state_dataframes = []

# Loop through each file in the folder and append the df to the list
for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(folder_path, file_name)
        df_state = pd.read_csv(file_path)
        state_dataframes.append(df_state)

# Combine all state DataFrames into one DataFrame
df_states = pd.concat(state_dataframes, ignore_index=True)
df_states
# Out:
#                                  name  \
# 0               Eagle Enterprises Inc
# 1               Eagle Enterprises Inc
# 2                  Alaska Tent & Tarp
# 3          Valley Dollar Plus & MORE!
# 4                  Sourdough Transfer
# ...                               ...
# 341207            Walmart Supercenter
# 341208  Foundation Building Materials
# 341209              Southern Iowa Oil
# 341210         Flying J Travel Center
# 341211                      Theisen's
#
#                                                   address  \
# 0       Eagle Enterprises Inc, 1041 Ocean Dr, Homer, A...
# 1       Eagle Enterprises Inc, 1041 Ocean Dr, Homer, A...
# 2       Alaska Tent & Tarp, 2424 E 5th Ave, Anchorage,...
# 3       Valley Dollar Plus & MORE!, 481 W Parks Hwy, W...
# 4       Sourdough Transfer, 600 Driveway St, Fairbanks...
# ...                                                   ...
# 341207  Walmart Supercenter, 2200 17th St, Spirit Lake...
# 341208  Foundation Building Materials, 4401 112th St, ...
# 341209  Southern Iowa Oil, 2130 Court Ave, Chariton, I...
# 341210  Flying J Travel Center, 8200 Northwest Blvd, D...
# 341211     Theisen's, 403 E Oskaloosa St, Pella, IA 50219
#
#                                       gmap_id  \
# 0       0x56c12d9331100c9b:0x1928f20e7115f388
# 1       0x56c12d9331100c9b:0x1928f20e7115f388
# 2       0x56c897916ab9b4d9:0x334e07a949ef65fc
# 3        0x56c8df0f2cbd1b53:0x53d601e0489e104
# 4       0x51324539aa87c7f1:0x75196ecfedd91c3f
# ...                                       ...
# 341207  0x878cb43f39734807:0x7c20fd817a06680a
# 341208  0x87ec27087c545371:0x3a5ffd1d59176776
# 341209  0x87e93bc31d68794f:0xe099b19a245c0f19
# 341210  0x87e3b56180231c17:0x7135d41221033ab8
# 341211  0x87ef307cf7f381df:0x8786dc8056756e84
#
#                                               description   latitude  \
# 0                                                     NaN  59.637164
# 1                                                     NaN  59.637164
# 2                                                     NaN  61.217106
# 3                                                     NaN  61.582763
# 4                                                     NaN  64.851457
# ...                                                   ...        ...
# 341207                                                NaN  43.424338
# 341208                                                NaN  41.641094
# 341209                                                NaN  41.014260
# 341210                                                NaN  41.602914
# 341211  Retailer stocking a wide range of home, farm &...  41.395948
#
#          longitude                                           category  \
# 0      -151.516859                            ['marine supply store']
# 1      -151.516859                            ['marine supply store']
# 2      -149.835767  ['fabric product manufacturer', 'aircraft supp...
# 3      -149.461998  ['dollar store', 'convenience store', 'grocery...
# 4      -147.725530  ['mover', 'moving and storage service', 'movin...
# ...            ...                                                ...
# 341207  -95.124478  ['department store', 'clothing store', 'craft ...
# 341208  -93.768668  ['building materials market', 'construction ma...
# 341209  -93.327017               ['gas station', 'convenience store']
# 341210  -90.624855  ['truck stop', 'convenience store', 'gas stati...
# 341211  -92.901603  ['department store', 'auto parts store', 'clot...
#
#         avg_rating  num_of_reviews price  \
# 0              4.7               3   NaN
# 1              4.7               3   NaN
# 2              4.4              18   NaN
# 3              3.9              26   NaN
# 4              4.5              28   NaN
# ...            ...             ...   ...
# 341207         3.7            1152     $
# 341208         4.5              18   NaN
# 341209         3.6              15   NaN
# 341210         3.9             933   NaN
# 341211         4.3             467   NaN
#
#                                                     hours  \
# 0       [['Wednesday', '8AM–5PM'], ['Thursday', '8AM–5...
# 1       [['Wednesday', '8AM–5PM'], ['Thursday', '8AM–5...
# 2       [['Monday', '8:30AM–5:30PM'], ['Tuesday', '8:3...
# 3       [['Sunday', '11AM–5PM'], ['Monday', '10AM–7PM'...
# 4       [['Sunday', 'Closed'], ['Monday', '8AM–5PM'], ...
# ...                                                   ...
# 341207  [['Saturday', '7AM–11PM'], ['Sunday', '7AM–11P...
# 341208  [['Friday', '7AM–4:30AM'], ['Saturday', 'Close...
# 341209                                                NaN
# 341210  [['Thursday', 'Open 24 hours'], ['Friday', 'Op...
# 341211  [['Thursday', '8AM–8PM'], ['Friday', '8AM–8PM'...
#
#                                                      MISC  \
# 0              {'Service options': ['In-store shopping']}
# 1              {'Service options': ['In-store shopping']}
# 2       {'Accessibility': ['Wheelchair accessible entr...
# 3       {'From the business': ['Identifies as veteran-...
# 4       {'Accessibility': ['Wheelchair accessible entr...
# ...                                                   ...
# 341207  {'Service options': ['Curbside pickup', 'In-st...
# 341208         {'Service options': ['In-store shopping']}
# 341209                                                NaN
# 341210  {'Service options': ['In-store shopping', 'Del...
# 341211  {'Service options': ['Curbside pickup', 'In-st...
#
#                           state  \
# 0             Open ⋅ Closes 5PM
# 1             Open ⋅ Closes 5PM
# 2         Closed ⋅ Opens 8:30AM
# 3       Closed ⋅ Opens 10AM Mon
# 4        Closed ⋅ Opens 8AM Mon
# ...                         ...
# 341207                      NaN
# 341208                      NaN
# 341209                      NaN
# 341210                      NaN
# 341211                      NaN
#
#                                          relative_results  \
# 0       ['0x56c12d9423ebd6a9:0x96b71d14c683ace0', '0x5...
# 1       ['0x56c12d9423ebd6a9:0x96b71d14c683ace0', '0x5...
# 2       ['0x56c897db88baae1f:0x45abf88c4d62a916', '0x5...
# 3       ['0x56c8984829b7a761:0x1bccd85b80a4a2bc', '0x5...
# 4       ['0x5132453a013fb1f3:0x1c66f7bcc441028b', '0x5...
# ...                                                   ...
# 341207  ['0x878cb45b61c0421b:0x63cece1607b24165', '0x8...
# 341208  ['0x87ec27087b63f6cb:0xab45fb285f06de23', '0x8...
# 341209  ['0x87e93ac50fb43091:0x5daba4ef211a0a0', '0x87...
# 341210  ['0x87e3b561451f0d83:0x2fbc08d29b5ead3b', '0x8...
# 341211  ['0x87ef3aac5bf421e9:0xb30642d12e24fb32', '0x8...
#
#                                                       url
# 0       https://www.google.com/maps/place//data=!4m2!3...
# 1       https://www.google.com/maps/place//data=!4m2!3...
# 2       https://www.google.com/maps/place//data=!4m2!3...
# 3       https://www.google.com/maps/place//data=!4m2!3...
# 4       https://www.google.com/maps/place//data=!4m2!3...
# ...                                                   ...
# 341207  https://www.google.com/maps/place//data=!4m2!3...
# 341208  https://www.google.com/maps/place//data=!4m2!3...
# 341209  https://www.google.com/maps/place//data=!4m2!3...
# 341210  https://www.google.com/maps/place//data=!4m2!3...
# 341211  https://www.google.com/maps/place//data=!4m2!3...
#
# [341212 rows x 15 columns]

# %%
# Dropping duplicate rows
df_states = df_states.drop_duplicates()
df_states
# Out:
#                                  name  \
# 0               Eagle Enterprises Inc
# 2                  Alaska Tent & Tarp
# 3          Valley Dollar Plus & MORE!
# 4                  Sourdough Transfer
# 5                  Sourdough Transfer
# ...                               ...
# 341207            Walmart Supercenter
# 341208  Foundation Building Materials
# 341209              Southern Iowa Oil
# 341210         Flying J Travel Center
# 341211                      Theisen's
#
#                                                   address  \
# 0       Eagle Enterprises Inc, 1041 Ocean Dr, Homer, A...
# 2       Alaska Tent & Tarp, 2424 E 5th Ave, Anchorage,...
# 3       Valley Dollar Plus & MORE!, 481 W Parks Hwy, W...
# 4       Sourdough Transfer, 600 Driveway St, Fairbanks...
# 5       Sourdough Transfer, 299 W 64th Ave, Anchorage,...
# ...                                                   ...
# 341207  Walmart Supercenter, 2200 17th St, Spirit Lake...
# 341208  Foundation Building Materials, 4401 112th St, ...
# 341209  Southern Iowa Oil, 2130 Court Ave, Chariton, I...
# 341210  Flying J Travel Center, 8200 Northwest Blvd, D...
# 341211     Theisen's, 403 E Oskaloosa St, Pella, IA 50219
#
#                                       gmap_id  \
# 0       0x56c12d9331100c9b:0x1928f20e7115f388
# 2       0x56c897916ab9b4d9:0x334e07a949ef65fc
# 3        0x56c8df0f2cbd1b53:0x53d601e0489e104
# 4       0x51324539aa87c7f1:0x75196ecfedd91c3f
# 5       0x56c89786087eb2b5:0xaa26d5f2a0dcfac6
# ...                                       ...
# 341207  0x878cb43f39734807:0x7c20fd817a06680a
# 341208  0x87ec27087c545371:0x3a5ffd1d59176776
# 341209  0x87e93bc31d68794f:0xe099b19a245c0f19
# 341210  0x87e3b56180231c17:0x7135d41221033ab8
# 341211  0x87ef307cf7f381df:0x8786dc8056756e84
#
#                                               description   latitude  \
# 0                                                     NaN  59.637164
# 2                                                     NaN  61.217106
# 3                                                     NaN  61.582763
# 4                                                     NaN  64.851457
# 5                                                     NaN  61.162996
# ...                                                   ...        ...
# 341207                                                NaN  43.424338
# 341208                                                NaN  41.641094
# 341209                                                NaN  41.014260
# 341210                                                NaN  41.602914
# 341211  Retailer stocking a wide range of home, farm &...  41.395948
#
#          longitude                                           category  \
# 0      -151.516859                            ['marine supply store']
# 2      -149.835767  ['fabric product manufacturer', 'aircraft supp...
# 3      -149.461998  ['dollar store', 'convenience store', 'grocery...
# 4      -147.725530  ['mover', 'moving and storage service', 'movin...
# 5      -149.885888  ['mover', 'moving and storage service', 'movin...
# ...            ...                                                ...
# 341207  -95.124478  ['department store', 'clothing store', 'craft ...
# 341208  -93.768668  ['building materials market', 'construction ma...
# 341209  -93.327017               ['gas station', 'convenience store']
# 341210  -90.624855  ['truck stop', 'convenience store', 'gas stati...
# 341211  -92.901603  ['department store', 'auto parts store', 'clot...
#
#         avg_rating  num_of_reviews price  \
# 0              4.7               3   NaN
# 2              4.4              18   NaN
# 3              3.9              26   NaN
# 4              4.5              28   NaN
# 5              4.2              18   NaN
# ...            ...             ...   ...
# 341207         3.7            1152     $
# 341208         4.5              18   NaN
# 341209         3.6              15   NaN
# 341210         3.9             933   NaN
# 341211         4.3             467   NaN
#
#                                                     hours  \
# 0       [['Wednesday', '8AM–5PM'], ['Thursday', '8AM–5...
# 2       [['Monday', '8:30AM–5:30PM'], ['Tuesday', '8:3...
# 3       [['Sunday', '11AM–5PM'], ['Monday', '10AM–7PM'...
# 4       [['Sunday', 'Closed'], ['Monday', '8AM–5PM'], ...
# 5       [['Sunday', 'Closed'], ['Monday', '8AM–5PM'], ...
# ...                                                   ...
# 341207  [['Saturday', '7AM–11PM'], ['Sunday', '7AM–11P...
# 341208  [['Friday', '7AM–4:30AM'], ['Saturday', 'Close...
# 341209                                                NaN
# 341210  [['Thursday', 'Open 24 hours'], ['Friday', 'Op...
# 341211  [['Thursday', '8AM–8PM'], ['Friday', '8AM–8PM'...
#
#                                                      MISC  \
# 0              {'Service options': ['In-store shopping']}
# 2       {'Accessibility': ['Wheelchair accessible entr...
# 3       {'From the business': ['Identifies as veteran-...
# 4       {'Accessibility': ['Wheelchair accessible entr...
# 5                                                     NaN
# ...                                                   ...
# 341207  {'Service options': ['Curbside pickup', 'In-st...
# 341208         {'Service options': ['In-store shopping']}
# 341209                                                NaN
# 341210  {'Service options': ['In-store shopping', 'Del...
# 341211  {'Service options': ['Curbside pickup', 'In-st...
#
#                           state  \
# 0             Open ⋅ Closes 5PM
# 2         Closed ⋅ Opens 8:30AM
# 3       Closed ⋅ Opens 10AM Mon
# 4        Closed ⋅ Opens 8AM Mon
# 5        Closed ⋅ Opens 8AM Mon
# ...                         ...
# 341207                      NaN
# 341208                      NaN
# 341209                      NaN
# 341210                      NaN
# 341211                      NaN
#
#                                          relative_results  \
# 0       ['0x56c12d9423ebd6a9:0x96b71d14c683ace0', '0x5...
# 2       ['0x56c897db88baae1f:0x45abf88c4d62a916', '0x5...
# 3       ['0x56c8984829b7a761:0x1bccd85b80a4a2bc', '0x5...
# 4       ['0x5132453a013fb1f3:0x1c66f7bcc441028b', '0x5...
# 5       ['0x56c897d2e3117e3d:0x2d77c9f7c8b90a70', '0x5...
# ...                                                   ...
# 341207  ['0x878cb45b61c0421b:0x63cece1607b24165', '0x8...
# 341208  ['0x87ec27087b63f6cb:0xab45fb285f06de23', '0x8...
# 341209  ['0x87e93ac50fb43091:0x5daba4ef211a0a0', '0x87...
# 341210  ['0x87e3b561451f0d83:0x2fbc08d29b5ead3b', '0x8...
# 341211  ['0x87ef3aac5bf421e9:0xb30642d12e24fb32', '0x8...
#
#                                                       url
# 0       https://www.google.com/maps/place//data=!4m2!3...
# 2       https://www.google.com/maps/place//data=!4m2!3...
# 3       https://www.google.com/maps/place//data=!4m2!3...
# 4       https://www.google.com/maps/place//data=!4m2!3...
# 5       https://www.google.com/maps/place//data=!4m2!3...
# ...                                                   ...
# 341207  https://www.google.com/maps/place//data=!4m2!3...
# 341208  https://www.google.com/maps/place//data=!4m2!3...
# 341209  https://www.google.com/maps/place//data=!4m2!3...
# 341210  https://www.google.com/maps/place//data=!4m2!3...
# 341211  https://www.google.com/maps/place//data=!4m2!3...
#
# [339899 rows x 15 columns]

# %%
# Keep only useful columns for df_states
columns_to_keep_states = ['gmap_id', 'latitude', 'longitude']
df_states = df_states[columns_to_keep_states]
df_states
# Out:
#                                       gmap_id   latitude   longitude
# 0       0x56c12d9331100c9b:0x1928f20e7115f388  59.637164 -151.516859
# 2       0x56c897916ab9b4d9:0x334e07a949ef65fc  61.217106 -149.835767
# 3        0x56c8df0f2cbd1b53:0x53d601e0489e104  61.582763 -149.461998
# 4       0x51324539aa87c7f1:0x75196ecfedd91c3f  64.851457 -147.725530
# 5       0x56c89786087eb2b5:0xaa26d5f2a0dcfac6  61.162996 -149.885888
# ...                                       ...        ...         ...
# 341207  0x878cb43f39734807:0x7c20fd817a06680a  43.424338  -95.124478
# 341208  0x87ec27087c545371:0x3a5ffd1d59176776  41.641094  -93.768668
# 341209  0x87e93bc31d68794f:0xe099b19a245c0f19  41.014260  -93.327017
# 341210  0x87e3b56180231c17:0x7135d41221033ab8  41.602914  -90.624855
# 341211  0x87ef307cf7f381df:0x8786dc8056756e84  41.395948  -92.901603
#
# [339899 rows x 3 columns]

# %%
# Load the shapefile for states
states_gdf = gpd.read_file("./state shapefile/cb_2018_us_state_5m.shp")

# Ensure the CRS of states_gdf is EPSG:4326 for consistency
states_gdf = states_gdf.to_crs(epsg=4326)

# Convert df_states to a GeoDataFrame by creating a geometry column from latitude and longitude
df_states = df_states.copy()  # Make a copy to avoid modifying the original DataFrame
df_states['geometry'] = df_states.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)
df_states_gdf = gpd.GeoDataFrame(df_states, geometry='geometry', crs="EPSG:4326")

# Ensure consistent data types for merging
df_states_gdf['gmap_id'] = df_states_gdf['gmap_id'].astype(str)

# Perform spatial intersection using overlay
df_states_with_state = gpd.overlay(df_states_gdf, states_gdf, how='intersection')

# Assign state names and keep only the relevant columns
df_states_with_state['state'] = df_states_with_state['NAME']
df_states = df_states_with_state[['gmap_id', 'latitude', 'longitude', 'state']]

# Final output
df_states
# Out:
#                                       gmap_id   latitude   longitude     state
# 0       0x56c12d9331100c9b:0x1928f20e7115f388  59.637164 -151.516859    Alaska
# 1       0x56c897916ab9b4d9:0x334e07a949ef65fc  61.217106 -149.835767    Alaska
# 2        0x56c8df0f2cbd1b53:0x53d601e0489e104  61.582763 -149.461998    Alaska
# 3       0x51324539aa87c7f1:0x75196ecfedd91c3f  64.851457 -147.725530    Alaska
# 4       0x56c89786087eb2b5:0xaa26d5f2a0dcfac6  61.162996 -149.885888    Alaska
# ...                                       ...        ...         ...       ...
# 339312   0x876c7f11b01f5fd3:0xc518fddc4300ac6  39.708073 -105.001341  Colorado
# 339313    0x876b890bc6933989:0xe6c93557f67b5d  39.861521 -105.080365  Colorado
# 339314  0x876ea112917cfa13:0xb823d5fc5b53ee02  40.394325 -104.718313  Colorado
# 339315  0x876c7f4ff031b1a7:0xd63c647c233a610b  39.724640 -105.019903  Colorado
# 339316   0x876c7c2a116bb8b1:0xf643ffcda102fb4  39.708523 -104.937060  Colorado
#
# [339317 rows x 4 columns]

# %%
# Load the review (health resource-related) data
df_review = pd.read_csv('./classed_review_2018.csv')
df_review
# Out:
#              user_id                        name                     time  \
# 0       1.171145e+20              Laura Gilinsky  2021-08-18 17:18:32.860
# 1       1.121227e+20                 Patty Damme  2018-01-05 16:51:25.395
# 2       1.021695e+20                  Megan Lynn  2021-05-27 03:20:33.316
# 3       1.151289e+20  Susan “SuzyQsLion” Woolery  2018-02-24 04:27:23.868
# 4       1.142903e+20             Courtney Scholl  2021-08-28 14:37:46.157
# ...              ...                         ...                      ...
# 290113  1.021095e+20                sarah ponton  2020-07-15 15:12:38.739
# 290114  1.079780e+20                   Andrea Go  2020-12-19 03:22:53.860
# 290115  1.075649e+20                Amber Wassam  2020-07-26 14:33:18.317
# 290116  1.022147e+20              Tawny Bottiger  2020-08-29 16:01:09.722
# 290117  1.025850e+20             Chris Whitfield  2019-11-13 00:12:02.742
#
#         rating                                               text  \
# 0          5.0  Elena kindly talked me through the custom opti...
# 1          4.0  It's quick in and out usually, the sell alcoho...
# 2          1.0    Still forcing masks after the mandate has ended
# 3          5.0  Carries cold drinks, fountain drinks, coffee, ...
# 4          2.0  Update 8/27:  We have a new mask mandate in Li...
# ...        ...                                                ...
# 290113     2.0                               Employees not masked
# 290114     5.0          Very clean and everyone was wearing masks
# 290115     1.0  I’m not allowed to buy groceries unless I wear...
# 290116     4.0                        but people not wearing mask
# 290117     5.0  10/10 would sit at a table by myself and write...
#
#                                                      pics  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 290113                                                NaN
# 290114  [{'url': ['https://lh5.googleusercontent.com/p...
# 290115                                                NaN
# 290116                                                NaN
# 290117                                                NaN
#
#                                                      resp  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       {'time': 1617157609725, 'text': 'Update: As wr...
# ...                                                   ...
# 290113                                                NaN
# 290114  {'time': 1608407500114, 'text': "Hi Andrea, we...
# 290115                                                NaN
# 290116                                                NaN
# 290117                                                NaN
#
#                                       gmap_id  keywords_mentioned  \
# 0       0x8793f3c9c4a6066d:0x5636690d1815fa0b                True
# 1       0x8796681daaba37f1:0x45d0ffe31b28ae63                True
# 2       0x87938b9da361a3d9:0x577157078adb3359                True
# 3       0x8776e8324b8c3ecf:0xdb935c6665556259                True
# 4       0x8796960819abf859:0x6e4e236c8ff7317f                True
# ...                                       ...                 ...
# 290113  0x89b36e6878ffd87f:0xad352c8e87e59213                True
# 290114  0x89b5efbfdf45c881:0x37d76a3f96510495                True
# 290115  0x89b5efbfdf45c881:0x37d76a3f96510495                True
# 290116  0x89b5efbfdf45c881:0x37d76a3f96510495                True
# 290117  0x89b63c1bab30660f:0x65081492263b5eed                True
#
#        mentioned_keywords  class
# 0                ['mask']      9
# 1             ['alcohol']      1
# 2                ['mask']      9
# 3             ['alcohol']      1
# 4                ['mask']      9
# ...                   ...    ...
# 290113           ['mask']      9
# 290114           ['mask']      9
# 290115           ['mask']      9
# 290116           ['mask']      9
# 290117         ['gloves']      9
#
# [290118 rows x 11 columns]

# %%
# Keeping only the specified columns
columns_review = ['gmap_id', 'text', 'time', 'class']
df_review = df_review[columns_review]
df_review
# Out:
#                                       gmap_id  \
# 0       0x8793f3c9c4a6066d:0x5636690d1815fa0b
# 1       0x8796681daaba37f1:0x45d0ffe31b28ae63
# 2       0x87938b9da361a3d9:0x577157078adb3359
# 3       0x8776e8324b8c3ecf:0xdb935c6665556259
# 4       0x8796960819abf859:0x6e4e236c8ff7317f
# ...                                       ...
# 290113  0x89b36e6878ffd87f:0xad352c8e87e59213
# 290114  0x89b5efbfdf45c881:0x37d76a3f96510495
# 290115  0x89b5efbfdf45c881:0x37d76a3f96510495
# 290116  0x89b5efbfdf45c881:0x37d76a3f96510495
# 290117  0x89b63c1bab30660f:0x65081492263b5eed
#
#                                                      text  \
# 0       Elena kindly talked me through the custom opti...
# 1       It's quick in and out usually, the sell alcoho...
# 2         Still forcing masks after the mandate has ended
# 3       Carries cold drinks, fountain drinks, coffee, ...
# 4       Update 8/27:  We have a new mask mandate in Li...
# ...                                                   ...
# 290113                               Employees not masked
# 290114          Very clean and everyone was wearing masks
# 290115  I’m not allowed to buy groceries unless I wear...
# 290116                        but people not wearing mask
# 290117  10/10 would sit at a table by myself and write...
#
#                            time  class
# 0       2021-08-18 17:18:32.860      9
# 1       2018-01-05 16:51:25.395      1
# 2       2021-05-27 03:20:33.316      9
# 3       2018-02-24 04:27:23.868      1
# 4       2021-08-28 14:37:46.157      9
# ...                         ...    ...
# 290113  2020-07-15 15:12:38.739      9
# 290114  2020-12-19 03:22:53.860      9
# 290115  2020-07-26 14:33:18.317      9
# 290116  2020-08-29 16:01:09.722      9
# 290117  2019-11-13 00:12:02.742      9
#
# [290118 rows x 4 columns]

# %%
# Dropping duplicate rows from df_reviews
df_review = df_review.drop_duplicates()
df_review
# Out:
#                                       gmap_id  \
# 0       0x8793f3c9c4a6066d:0x5636690d1815fa0b
# 1       0x8796681daaba37f1:0x45d0ffe31b28ae63
# 2       0x87938b9da361a3d9:0x577157078adb3359
# 3       0x8776e8324b8c3ecf:0xdb935c6665556259
# 4       0x8796960819abf859:0x6e4e236c8ff7317f
# ...                                       ...
# 290113  0x89b36e6878ffd87f:0xad352c8e87e59213
# 290114  0x89b5efbfdf45c881:0x37d76a3f96510495
# 290115  0x89b5efbfdf45c881:0x37d76a3f96510495
# 290116  0x89b5efbfdf45c881:0x37d76a3f96510495
# 290117  0x89b63c1bab30660f:0x65081492263b5eed
#
#                                                      text  \
# 0       Elena kindly talked me through the custom opti...
# 1       It's quick in and out usually, the sell alcoho...
# 2         Still forcing masks after the mandate has ended
# 3       Carries cold drinks, fountain drinks, coffee, ...
# 4       Update 8/27:  We have a new mask mandate in Li...
# ...                                                   ...
# 290113                               Employees not masked
# 290114          Very clean and everyone was wearing masks
# 290115  I’m not allowed to buy groceries unless I wear...
# 290116                        but people not wearing mask
# 290117  10/10 would sit at a table by myself and write...
#
#                            time  class
# 0       2021-08-18 17:18:32.860      9
# 1       2018-01-05 16:51:25.395      1
# 2       2021-05-27 03:20:33.316      9
# 3       2018-02-24 04:27:23.868      1
# 4       2021-08-28 14:37:46.157      9
# ...                         ...    ...
# 290113  2020-07-15 15:12:38.739      9
# 290114  2020-12-19 03:22:53.860      9
# 290115  2020-07-26 14:33:18.317      9
# 290116  2020-08-29 16:01:09.722      9
# 290117  2019-11-13 00:12:02.742      9
#
# [290117 rows x 4 columns]

# %%
# Merge both dfs based on 'gmap_id' column
df_merged = pd.merge(df_states, df_review, on='gmap_id', how='inner')
df_merged
# Out:
#                                       gmap_id   latitude   longitude  \
# 0       0x51324539aa87c7f1:0x75196ecfedd91c3f  64.851457 -147.725530
# 1       0x56c7b672b51a2b31:0x4f0e143cc4dd950c  60.489770 -149.819629
# 2       0x56c897a7c3f17fd3:0x34b32ebc391344dd  61.182368 -149.837275
# 3       0x56c65d36d12e1d61:0x21fb4a346d19cf9f  60.535471 -150.744274
# 4       0x513245425df672cf:0x766fc682ee2f506a  64.850711 -147.693889
# ...                                       ...        ...         ...
# 289914   0x876c7c2a116bb8b1:0xf643ffcda102fb4  39.708523 -104.937060
# 289915   0x876c7c2a116bb8b1:0xf643ffcda102fb4  39.708523 -104.937060
# 289916   0x876c7c2a116bb8b1:0xf643ffcda102fb4  39.708523 -104.937060
# 289917   0x876c7c2a116bb8b1:0xf643ffcda102fb4  39.708523 -104.937060
# 289918   0x876c7c2a116bb8b1:0xf643ffcda102fb4  39.708523 -104.937060
#
#            state                                               text  \
# 0         Alaska  No one was wearing masks and everyone was on t...
# 1         Alaska  Friendly staff, great selection of items and t...
# 2         Alaska  Lake Otis Pharmacy has really shined since the...
# 3         Alaska  Went here today to get some Childrens Ibuprofe...
# 4         Alaska  They need to make up their mind on the mask rules
# ...          ...                                                ...
# 289914  Colorado  I went there today and saw 3 different employe...
# 289915  Colorado  They stopped limiting the number of people all...
# 289916  Colorado                              Workers wearing masks
# 289917  Colorado  It is so beyond frustrating trying to find thi...
# 289918  Colorado  Shelves are not stocked with groceries, clothi...
#
#                            time  class
# 0       2020-11-12 22:10:18.770      9
# 1       2021-05-21 19:39:33.222      1
# 2       2020-04-29 22:34:43.845     -1
# 3       2018-07-13 00:22:40.598     -1
# 4       2021-05-22 00:49:20.969      9
# ...                         ...    ...
# 289914  2020-05-11 21:06:07.550      9
# 289915  2020-09-15 21:32:22.057      9
# 289916  2020-06-04 17:22:35.856      9
# 289917  2019-06-29 19:32:05.895     -1
# 289918  2018-10-23 20:39:50.201     -1
#
# [289919 rows x 7 columns]

# %%
# Convert the time column to datetime format
df_merged['time'] = pd.to_datetime(df_merged['time'])

# Function to calculate the review count and average sentiment for each state, per month
def calculate_monthly_sentiment(df):
    # Extract year and month from the time column
    df['month'] = df['time'].dt.to_period('M')

    # Group by state and year_month, calculate review count and sentiment
    grouped_df = df.groupby(['state', 'month']).agg(
        review_count=('gmap_id', 'size'),  # count the number of reviews
        total_sentiment=('class', lambda x: (x == 1).sum() - (x == -1).sum())  # calculate the total sentiment
    ).reset_index()

    # Calculate the average sentiment
    grouped_df['average_sentiment'] = grouped_df['total_sentiment'] / grouped_df['review_count']

    # Filter out months with less than 10 reviews
    filtered_df = grouped_df[grouped_df['review_count'] > 10]

    return filtered_df

# Calculate the monthly sentiment data
result_df = calculate_monthly_sentiment(df_merged)

# Display the final df
result_df
# Out:
#         state    month  review_count  total_sentiment  average_sentiment
# 0     Alabama  2018-01            17               -3          -0.176471
# 1     Alabama  2018-02            17               -6          -0.352941
# 2     Alabama  2018-03            16                4           0.250000
# 3     Alabama  2018-04            12               -2          -0.166667
# 4     Alabama  2018-05            24              -12          -0.500000
# ...       ...      ...           ...              ...                ...
# 2206  Wyoming  2020-12            39                0           0.000000
# 2207  Wyoming  2021-01            34               -4          -0.117647
# 2208  Wyoming  2021-02            22               -1          -0.045455
# 2209  Wyoming  2021-03            30                3           0.100000
# 2210  Wyoming  2021-04            20               -2          -0.100000
#
# [1743 rows x 5 columns]

# %%
# Now proceed with filtering as usual
result_df = result_df[(result_df['month'] >= '2020-04') & (result_df['month'] <= '2021-05')]
result_df
# Out:
#         state    month  review_count  total_sentiment  average_sentiment
# 27    Alabama  2020-04            50              -10          -0.200000
# 28    Alabama  2020-05           173              -19          -0.109827
# 29    Alabama  2020-06           209              -26          -0.124402
# 30    Alabama  2020-07           457              -35          -0.076586
# 31    Alabama  2020-08           372               -8          -0.021505
# ...       ...      ...           ...              ...                ...
# 2206  Wyoming  2020-12            39                0           0.000000
# 2207  Wyoming  2021-01            34               -4          -0.117647
# 2208  Wyoming  2021-02            22               -1          -0.045455
# 2209  Wyoming  2021-03            30                3           0.100000
# 2210  Wyoming  2021-04            20               -2          -0.100000
#
# [700 rows x 5 columns]

# %%
# Save the 'filtered_county' as a CSV file
file_path = './sentiment_validation.csv'
result_df.to_csv(file_path, index=False)

file_path
# Out:
# './sentiment_validation.csv'
